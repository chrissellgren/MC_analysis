# %%
##########################################

# VXDBplots.py
# Imports local data from output root files and extracts contents to create a plot
# June 27, 2023
# Chris Sellgren, UCSB/LBNL/IRIS-HEP

##########################################

import ROOT as R
import math
import os
import numpy as np

R.gStyle.SetOptStat(0)
R.gStyle.SetGridColor(14)
R.gStyle.SetPadRightMargin(0.03)
R.gStyle.SetPadLeftMargin(0.12)

# hard coded values for the sensor layer areas
sens_area = {}
sens_area.update({('b',l): 1e-2*130*a for l, a in enumerate([16*13,15*23,21*24,29*24])})

sens_area_ib = {}
sens_area_ib.update({('b',l): a for l, a in enumerate([8117.85,22034.16,51678.81])})
    
# set canvas
C = R.TCanvas('canvas','',1500,1500)
# R.gStyle.SetPalette(R.kBird)
C.SetLeftMargin(0.13)
C.SetRightMargin(0.1)
C.SetGrid(1,1)

# pull files from local drive
STUDY_NAME = "10tev_newrun"
DIR_IN = '/Users/chris/Desktop/MC/data/myruns_vxdbstudy/' + STUDY_NAME
DIR_OUT = os.path.join('/Users/chris/Desktop/MC/data/plots')
NAMES = ['notimingcut','timingcut', 'loosecluster','tightcluster']
files_in = [R.TFile(os.path.join(DIR_IN,f'histograms_{n}.root')) for n in NAMES]

# extract contents from files
nH = len(NAMES)
histos_vb = [files_in[i].MyTrackPerf.clusters_vb.numhits_by_layer for i in range(nH)]
histos_ib = [files_in[i].MyTrackPerf.clusters_ib.numhits_by_layer for i in range(nH)]

        
for h in histos_ib:  
    # noramlize by sensor area, shift bins by 4.
    for l in range(3):
        h.SetBinContent(l+5, h.GetBinContent(l+1) / sens_area_ib[('b', l)])
        h.SetBinContent(l+1, 0)
        
for iH, h in enumerate(histos_vb):
    h.Draw()
    
    h.SetBinContent(4, h.GetBinContent(5))
    
    # noramlize by sensor area
    for l in range(4):
        h.SetBinContent(l+5, 0)
        h.SetBinContent(l+1, h.GetBinContent(l+1) / sens_area[('b', l)])
    
    h.Add(histos_ib[iH])
        
# make plot
names = [
    't < 15 ns',
    't < 90 ps (VX), t < 480ps (IT)',
    'timing + loose cluster cut',
    'timing + tight cluster cut',
]

R.gStyle.SetGridColor(12)
C.Clear()
C.cd()
C.SetGrid(1)

leg = R.TLegend(0.515, 0.74, 0.9, 0.9)
colors = [12, R.kAzure+2, R.kPink+2, R.kAzure+7, R.kTeal+2]
fills = [17,R.kAzure+7, R.kOrange+1, R.kTeal+2]
# colors = [1, 11, 15]
# fills = [0, 12, 16]
yMax = 1e4
h_ax = R.TH1F('h_ax', ';Layer index;Hit density [cm^{-2}]', 7, 0, 7)
#h_ax.GetYaxis().SetMaxDigits(4)
C.SetLogy(False)
h_ax.SetAxisRange(0, 50, 'Y')
# Optimising the X axis
a = h_ax.GetXaxis()
#a.SetNdivisions(-208)
# Drawing the axes
h_ax.Draw('AXIS')
h_ax.Draw('AXIG same')
# Drawing
for iT, h in enumerate(histos_vb):
    h.SetLineColor(1)
    h.SetFillColor(fills[iT])
    h.SetLineWidth(2)
    leg_type = 'F'
    leg.AddEntry(h, names[iT], leg_type)
    h.Draw('HIST same')
h_ax.Draw('AXIG same')
leg.Draw()
C.Draw()
C.RedrawAxis()
# Drawing text labels
t1 = R.TText(2, 5, 'VX Barrel')
t2 = R.TText(5.5, 5, 'IT Barrel')

for t in [t1,t2]:
    t.SetTextAlign(22)
    t.SetTextColor(1)
    t.Draw()
    
# Drawing vertical separator
l = R.TLine(4, 0, 4, 40)
l.SetLineWidth(3)
l.SetLineColor(1)
l.Draw()
C.SaveAs(os.path.join(DIR_OUT,STUDY_NAME+"_split_lineary.png"))
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /Users/chris/Desktop/MC/data/plots/10tev_newrun_split_lineary.png has been created

# %%
##########################################

# VXDBplots.py
# Imports local data from output root files and extracts contents to create a plot
# June 27, 2023
# Chris Sellgren, UCSB/LBNL/IRIS-HEP

##########################################

import ROOT as R
import math
import os
import numpy as np

R.gStyle.SetOptStat(0)
R.gStyle.SetGridColor(14)
R.gStyle.SetPadRightMargin(0.03)
R.gStyle.SetPadLeftMargin(0.12)

# hard coded values for the sensor layer areas
sens_area = {}
sens_area.update({('b',l): 1e-2*130*a for l, a in enumerate([16*13,15*23,21*24,29*24])})

sens_area_ib = {}
sens_area_ib.update({('b',l): a for l, a in enumerate([8117.85,22034.16,51678.81])})
    
# set canvas
C = R.TCanvas('canvas','',1500,1500)
# R.gStyle.SetPalette(R.kBird)
C.SetLeftMargin(0.13)
C.SetRightMargin(0.1)
C.SetGrid(1,1)

# pull files from local drive
STUDY_NAME = "10tev_newrun"
DIR_IN = '/Users/chris/Desktop/MC/data/myruns_vxdbstudy/' + STUDY_NAME
DIR_OUT = os.path.join('/Users/chris/Desktop/MC/data/plots')
NAMES = ['notimingcut','timingcut', 'loosecluster','tightcluster']
files_in = [R.TFile(os.path.join(DIR_IN,f'histograms_{n}.root')) for n in NAMES]

# extract contents from files
nH = len(NAMES)
histos_vb = [files_in[i].MyTrackPerf.clusters_vb.numhits_by_layer for i in range(nH)]
histos_ib = [files_in[i].MyTrackPerf.clusters_ib.numhits_by_layer for i in range(nH)]

        
for h in histos_ib:  
    # noramlize by sensor area, shift bins by 4.
    for l in range(3):
        h.SetBinContent(l+5, h.GetBinContent(l+1))
        h.SetBinContent(l+1, 0)
        
for iH, h in enumerate(histos_vb):
    h.Draw()
    
    h.SetBinContent(4, h.GetBinContent(5))
    
    # noramlize by sensor area
    for l in range(4):
        h.SetBinContent(l+5, 0)
    
    h.Add(histos_ib[iH])
        
# make plot
names = [
    't < 15 ns',
    't < 90 ps (VX), t < 480ps (IT)',
    'timing + loose cluster cut',
    'timing + tight cluster cut',
]

R.gStyle.SetGridColor(12)
C.Clear()
C.cd()
C.SetGrid(1)

leg = R.TLegend(0.3, 0.74, 0.65, 0.9)
colors = [12, R.kAzure+2, R.kPink+2, R.kAzure+7, R.kTeal+2]
fills = [17,R.kAzure+7, R.kOrange+1, R.kTeal+2]
# colors = [1, 11, 15]
# fills = [0, 12, 16]
yMax = 1e7
h_ax = R.TH1F('h_ax', ';Layer index;Total Hit Multiplicity (1 event)', 7, 0, 7)
#h_ax.GetYaxis().SetMaxDigits(4)
C.SetLogy(True)
h_ax.SetAxisRange(1e3, 1e7, 'Y')
# Optimising the X axis
a = h_ax.GetXaxis()
#a.SetNdivisions(-208)
# Drawing the axes
h_ax.Draw('AXIS')
h_ax.Draw('AXIG same')
# Drawing
for iT, h in enumerate(histos_vb):
    h.SetLineColor(1)
    h.SetFillColor(fills[iT])
    h.SetLineWidth(2)
    leg_type = 'F'
    leg.AddEntry(h, names[iT], leg_type)
    h.Draw('HIST same')
h_ax.Draw('AXIG same')
leg.Draw()
C.Draw()
C.RedrawAxis()
# Drawing text labels
t1 = R.TText(2, 5, 'VX Barrel')
t2 = R.TText(5.5, 5, 'IT Barrel')

for t in [t1,t2]:
    t.SetTextAlign(22)
    t.SetTextColor(1)
    t.Draw()
    
# Drawing vertical separator
l = R.TLine(4, 0, 4, 1.5e6)
l.SetLineWidth(3)
l.SetLineColor(1)
l.Draw()
C.SaveAs(os.path.join(DIR_OUT,STUDY_NAME+"totalmult_logy.png"))
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file /Users/chris/Desktop/MC/data/plots/10tev_newruntotalmult_logy.png has been created
